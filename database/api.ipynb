# %%
endpt="https://api.notion.com/v1/databases/0e2c8717f10341a2a2d30f48eb2c6677"

# %%
import requests
response=requests.get(endpt)

# %%
response
# Out:
# <Response [401]>

# %%
response.text
# Out:
# '{"object":"error","status":401,"code":"unauthorized","message":"API token is invalid."}'

# %%
"secret_jPevBhPSffLQfCwuYmflMcCL19Ei6VHRpzCaTbkWQUf"

# %%
response=requests.get(endpt,params={"Authorization":"Bearer "+token})

# %%
response
# Out:
# <Response [401]>

# %%
response=requests.get(endpt,params={"Authorization":"Bearer secret_jPevBhPSffLQfCwuYmflMcCL19Ei6VHRpzCaTbkWQUf"})

# %%
response.text
# Out:
# '{"object":"error","status":401,"code":"unauthorized","message":"API token is invalid."}'

# %%
import os
from notion_client import Client

notion = Client(auth="secret_oPnTR8UwwPWeDeJReXH7rZwRb2ILunhXd35AQOn2xmY")

# %%
db=notion.pages.retrieve("0e2c8717f10341a2a2d30f48eb2c6677")
type(db)
# Out:
# dict

# %%
res=notion.blocks.children.list("0e2c8717f10341a2a2d30f48eb2c6677")["results"]
l=[(r["id"],r[tuple(r.keys())[10]]["title"]) for r in res if r["type"]=="child_page" or r["type"]=="child_database"]

# %%
l
# Out:
# [('6dcd52c2-1fa7-48d8-8223-9b0cf057104b', 'Spirit Domains'),
#  ('0479657d-9e72-4ff5-8603-f8e2993860e2', 'Class Paths'),
#  ('3b66c0a5-ff9a-42ac-a5f4-7a262c62b27a', 'Effects'),
#  ('1da81c78-e793-4c4c-a214-4477e5efcf8b', 'Durations'),
#  ('b46cefa2-bf34-4557-b2c5-fd362d7eb7b9', 'Ranges'),
#  ('4eaa6b73-c3c8-4189-943d-e75ed709d7eb', 'Class Features'),
#  ('04a91868-699f-4afc-8c02-80ff4ac1e3ad', 'Tag Features'),
#  ('3df41ba0-adef-41da-89da-5873f4b7f7b0', 'Classes'),
#  ('367c52ae-497f-430b-98cc-c7716c8cae3f', 'Backgrounds'),
#  ('194cfc4a-2a7e-49c7-a3bd-a3f7d65fd870', 'Skills'),
#  ('c932f3aa-6db5-4aa2-a4ef-ad6fd38a2c63', 'Tags'),
#  ('0c18e1f7-462e-45a0-ba2a-025e9d25184a', 'Attributes')]

# %%
r=notion.databases.query("367c52ae-497f-430b-98cc-c7716c8cae3f")

# %%
r
# Out:
# {'object': 'list',
#  'results': [{'object': 'page',
#    'id': '09d60eaa-9d79-4328-9729-d432cd205cdf',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:51:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Everyone Has a Price:', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Everyone Has a Price:',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ' You can pay people 75 Gold to function as a scroll of Charm Person.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ' You can pay people 75 Gold to function as a scroll of Charm Person.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '515e1331-adf8-467f-a196-4c848d6e43bb'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': None},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '9fc5e86c-665d-44ea-8bbf-1b3ddd9bcd54'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Merchant', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Merchant',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Merchant-09d60eaa9d7943289729d432cd205cdf'},
#   {'object': 'page',
#    'id': '143de443-a9b3-4440-ba9f-1439d369728e',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:51:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Relentless Endurance: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Relentless Endurance: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'Whenever you would drop unconscious, you can make an endurance check, with the DC equal to (20 - 2* the number of HP you had before the attack).\xa0 If you succeed, you remain conscious at 1 HP, though any injury effects remain.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Whenever you would drop unconscious, you can make an endurance check, with the DC equal to (20 - 2* the number of HP you had before the attack).\xa0 If you succeed, you remain conscious at 1 HP, though any injury effects remain.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'ceb69b2f-42ef-409d-b9f9-7dae9ea60ab2'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': None},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'd4192952-a0ac-45bf-9403-3b0f0763e530'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Soldier', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Soldier',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Soldier-143de443a9b34440ba9f1439d369728e'},
#   {'object': 'page',
#    'id': '235dcbb7-8333-440e-afb4-e9e8f9967964',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:59:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Darkvision:', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Darkvision:',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ' You can see in the dark out to a range of 60 feet.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ' You can see in the dark out to a range of 60 feet.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'b79ce121-e8fb-49b8-904c-d300a1498c7e'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'ce6554ff-c2e8-4672-af92-22307e8c8af1'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Spirit-Blooded', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Spirit-Blooded',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Spirit-Blooded-235dcbb78333440eafb4e9e8f9967964'},
#   {'object': 'page',
#    'id': '498890d8-1246-41a2-9c19-723a6a5696c0',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:58:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Mask of the Wild: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Mask of the Wild: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'You can hide in natural settings so long as you are at least partially obscured.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'You can hide in natural settings so long as you are at least partially obscured.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '5ef90201-d601-4605-b4c0-b6814ffbdb1a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '810a3672-b911-47ae-9452-aa4a843bd7be'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Hermit', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Hermit',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Hermit-498890d8124641a29c19723a6a5696c0'},
#   {'object': 'page',
#    'id': '55fec94a-0ee0-4085-bc52-ff7816b2b7bb',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:53:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Hide in Plain Sight: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Hide in Plain Sight: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'You can hide if you are only lightly obscured in an urban setting.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'You can hide if you are only lightly obscured in an urban setting.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'f3d90b78-7b8d-4c50-b67b-2ff2767cff4a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'bca6285f-2134-4e2e-99aa-5643cd67297f'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Urchin', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Urchin',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Urchin-55fec94a0ee04085bc52ff7816b2b7bb'},
#   {'object': 'page',
#    'id': '66a54a28-5fb6-4d43-8484-eafbdfc41f74',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:57:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Social Graces:', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Social Graces:',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ' Pick one:\n• Whenever you notice that someone is lying (through an Insight check or otherwise) you can attempt a Charisma (Persuasion) check to trap them conversationally, revealing the lie\n• Whenever you succeed on a Charisma (Persuasion) check to ingratiate yourself with someone, you can slip small lies about yourself or your companions into the conversation without having to attempt a Charisma (Deception) check\n• Whenever you attempt a Charisma (Deception) check, you are aware of how well your lies landed, and what the sticking points are, if any.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ' Pick one:\n• Whenever you notice that someone is lying (through an Insight check or otherwise) you can attempt a Charisma (Persuasion) check to trap them conversationally, revealing the lie\n• Whenever you succeed on a Charisma (Persuasion) check to ingratiate yourself with someone, you can slip small lies about yourself or your companions into the conversation without having to attempt a Charisma (Deception) check\n• Whenever you attempt a Charisma (Deception) check, you are aware of how well your lies landed, and what the sticking points are, if any.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '5ef90201-d601-4605-b4c0-b6814ffbdb1a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'c0d4ca7e-27d3-41da-baa3-08cefdc23e8a'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Courtier', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Courtier',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Courtier-66a54a285fb64d438484eafbdfc41f74'},
#   {'object': 'page',
#    'id': '66c2178b-7365-481c-a2cf-3f7d3f399cad',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:59:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Charmer', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Charmer',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ': You may attempt Persuasion checks to replicate the effect of the Calm Emotions spell, so long as every target is humanoid. Targets oppose with Insight.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ': You may attempt Persuasion checks to replicate the effect of the Calm Emotions spell, so long as every target is humanoid. Targets oppose with Insight.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '06911990-9f2d-494f-9d08-77c268d3c2ad'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '4c0961a0-b36b-4425-ad3d-d00cbf6f1f73'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Entertainer', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Entertainer',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Entertainer-66c2178b7365481ca2cf3f7d3f399cad'},
#   {'object': 'page',
#    'id': '83c7f04e-d03f-478a-b7c2-04c173c640d7',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:52:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Helpful Advice: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Helpful Advice: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'Whenever someone makes a check with a skill you have proficiency with, you can attempt to help them for 10 ticks. You make the same check. If you succeed, they gain advantage on their check. If you fail, they gain disadvantage.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Whenever someone makes a check with a skill you have proficiency with, you can attempt to help them for 10 ticks. You make the same check. If you succeed, they gain advantage on their check. If you fail, they gain disadvantage.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '515e1331-adf8-467f-a196-4c848d6e43bb'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 10},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'd766b75d-c331-4204-a5bd-74342d9c97b9'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Scholar', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Scholar',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Scholar-83c7f04ed03f478ab7c204c173c640d7'},
#   {'object': 'page',
#    'id': '8c87ce0c-5087-4d91-b5cc-ac927719f4ef',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:56:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Stone’s Endurance:', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Stone’s Endurance:',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ' After gaining an injury, you can use your reaction to make an Endurance check, rerolling the injury with a bonus equal to (18 - your result).',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ' After gaining an injury, you can use your reaction to make an Endurance check, rerolling the injury with a bonus equal to (18 - your result).',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'ceb69b2f-42ef-409d-b9f9-7dae9ea60ab2'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '2f98193a-3e32-4273-bc5f-54b949e05e03'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Laborer', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Laborer',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Laborer-8c87ce0c50874d91b5ccac927719f4ef'},
#   {'object': 'page',
#    'id': 'ad5894cf-3bb8-448e-ab81-2086cdd722ea',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:53:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Make the Best of It: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Make the Best of It: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'Once per session you can swap an HM point for a Hero Point.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Once per session you can swap an HM point for a Hero Point.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'b79ce121-e8fb-49b8-904c-d300a1498c7e'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '2ddf470b-75ea-4ca4-8c6a-8acd84531142'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Slave', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Slave',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Slave-ad5894cf3bb8448eab812086cdd722ea'},
#   {'object': 'page',
#    'id': 'b47adc33-7171-46aa-843d-9713f1e250ba',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:56:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Pure Faith: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Pure Faith: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'You have advantage on Composure, Perception and Insight checks to stave off doubt, see through illusions, etc.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'You have advantage on Composure, Perception and Insight checks to stave off doubt, see through illusions, etc.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '515e1331-adf8-467f-a196-4c848d6e43bb'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'a3940fb4-1a63-4d3d-8a6e-981ac8c529a7'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Acolyte', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Acolyte',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Acolyte-b47adc33717146aa843d9713f1e250ba'},
#   {'object': 'page',
#    'id': 'c89bb383-dbe6-4d3f-8fd8-b973b7f5ff9c',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:58:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Powerful Swings: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Powerful Swings: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'Whenever you score a critical hit, you deal an additional HP of damage.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Whenever you score a critical hit, you deal an additional HP of damage.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'ceb69b2f-42ef-409d-b9f9-7dae9ea60ab2'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'aefde7f4-dfa5-4588-965c-0a9a27766b4e'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Reaver', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Reaver',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Reaver-c89bb383dbe64d3f8fd8b973b7f5ff9c'},
#   {'object': 'page',
#    'id': 'd337469c-51a9-4e1b-ab60-3712745f1c28',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:54:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Dirty Trick: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Dirty Trick: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': "As a 3 tick action, you can attempt a Deception check opposed by a target's Insight, so long as the target is in melee range. If you succeed, your next attack against the target has advantage.",
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': "As a 3 tick action, you can attempt a Deception check opposed by a target's Insight, so long as the target is in melee range. If you succeed, your next attack against the target has advantage.",
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'f3d90b78-7b8d-4c50-b67b-2ff2767cff4a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 3},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '41f2bca1-7e61-4c4a-a18a-54ef2e5e5ea5'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Criminal', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Criminal',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Criminal-d337469c51a94e1bab603712745f1c28'},
#   {'object': 'page',
#    'id': 'd98b8b77-41c4-49a5-99ac-eac4eba64904',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:57:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Mask of Many Faces:', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Mask of Many Faces:',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ' You can use a disguise kit to alter how you look extensively, even imitating a specific person.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ' You can use a disguise kit to alter how you look extensively, even imitating a specific person.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '06911990-9f2d-494f-9d08-77c268d3c2ad'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '1fa2dac5-59d3-4353-b8dc-1fb5d8f03c34'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Spy', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Spy',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Spy-d98b8b7741c449a599aceac4eba64904'},
#   {'object': 'page',
#    'id': 'da0574c9-3355-4644-9618-3b44b355a095',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:51:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Royal Blood', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Royal Blood',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': ': If you fail a check, you can attempt a DC 17 Composure check. If you succeed, you can re-attempt the roll, with advantage. If you fail, or fail the subsequent check, you take a hit point of damage, with no injury.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': ': If you fail a check, you can attempt a DC 17 Composure check. If you succeed, you can re-attempt the roll, with advantage. If you fail, or fail the subsequent check, you take a hit point of damage, with no injury.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '06911990-9f2d-494f-9d08-77c268d3c2ad'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'c002c2e2-b153-4cc1-b7cd-e6082280fe4f'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Noble', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Noble',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Noble-da0574c93355464496183b44b355a095'},
#   {'object': 'page',
#    'id': 'db46f2ec-25ef-42d9-903c-70d1f88c5c8d',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:54:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Step of the Wild: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Step of the Wild: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'Whenever you take a move action, you move as though you had spend 2 more ticks on the action.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Whenever you take a move action, you move as though you had spend 2 more ticks on the action.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': '5ef90201-d601-4605-b4c0-b6814ffbdb1a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '29b03a16-ea6e-436d-8dd1-442322ca6bee'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Scout', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Scout',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Scout-db46f2ec25ef42d9903c70d1f88c5c8d'},
#   {'object': 'page',
#    'id': 'ec0c372c-eb8b-46cb-b064-c4883096e482',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:51:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Materials at Cost: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Materials at Cost: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'You can spend gold to replicate the effects of Fabricate and Creation, at 3/4ths the normal cost.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'You can spend gold to replicate the effects of Fabricate and Creation, at 3/4ths the normal cost.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'b79ce121-e8fb-49b8-904c-d300a1498c7e'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': '4e229802-ec97-4144-93ff-0ae863e98eb2'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Artisan', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Artisan',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Artisan-ec0c372ceb8b46cbb064c4883096e482'},
#   {'object': 'page',
#    'id': 'f2aec8db-e632-4257-ab79-f6514f6270c8',
#    'created_time': '2023-02-07T19:47:00.000Z',
#    'last_edited_time': '2023-02-08T21:55:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'last_edited_by': {'object': 'user',
#     'id': 'a8b8b769-d29e-42e1-88b2-1613d6a9e4bd'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '367c52ae-497f-430b-98cc-c7716c8cae3f'},
#    'archived': False,
#    'properties': {'Feature': {'id': 'gLx%5E',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': 'Sea Legs: ', 'link': None},
#        'annotations': {'bold': True,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Sea Legs: ',
#        'href': None},
#       {'type': 'text',
#        'text': {'content': 'If you would be knocked prone, you can use your reaction to be pushed 10 feet.\xa0 If you would be subject to forced movement, you can use your reaction to instead fall prone.',
#         'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'If you would be knocked prone, you can use your reaction to be pushed 10 feet.\xa0 If you would be subject to forced movement, you can use your reaction to instead fall prone.',
#        'href': None}]},
#     'Attributes': {'id': 'gl%3Bd',
#      'type': 'relation',
#      'relation': [{'id': 'f3d90b78-7b8d-4c50-b67b-2ff2767cff4a'}],
#      'has_more': False},
#     'Ticks': {'id': 'nVTN', 'type': 'number', 'number': 0},
#     'Skills': {'id': 'ugW%3B',
#      'type': 'relation',
#      'relation': [{'id': 'f254212e-572a-41ca-9686-917387297673'}],
#      'has_more': False},
#     '\ufeffName': {'id': 'title',
#      'type': 'title',
#      'title': [{'type': 'text',
#        'text': {'content': 'Sailor', 'link': None},
#        'annotations': {'bold': False,
#         'italic': False,
#         'strikethrough': False,
#         'underline': False,
#         'code': False,
#         'color': 'default'},
#        'plain_text': 'Sailor',
#        'href': None}]}},
#    'url': 'https://www.notion.so/Sailor-f2aec8dbe6324257ab79f6514f6270c8'}],
#  'next_cursor': None,
#  'has_more': False,
#  'type': 'page',
#  'page': {}}
